# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.read_csv('C:\school\Vakken\MachineLearning\Torcs-client\csv\\berniw hist 1.forza.1-laps.csv', sep=';')
df.head()

loss_data = df[['speedGlobalX']]
loss_data = df[['speedX']]
plt.plot(loss_data, label = "speedX")
# plt.plot(test_losses, label = "test_loss")
plt.xlabel('Time')
plt.ylabel('Speed')
plt.show()
